# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn import metrics
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
from gensim.models import TfidfModel
import re

from tqdm import tqdm
from random import randint as rand

lemmatizer = WordNetLemmatizer()
newsgroups_train = fetch_20newsgroups(subset='all',
                                      categories=['alt.atheism',
                                                  # 'comp.graphics',
                                                  # 'comp.os.ms-windows.misc',
                                                  'comp.sys.ibm.pc.hardware',
                                                  # 'comp.sys.mac.hardware',
                                                  # 'comp.windows.x',
                                                  # 'misc.forsale',
                                                  'rec.autos',
                                                  # 'rec.motorcycles',
                                                  'rec.sport.baseball'],
                                      remove=("header",))


# добавить Bert, в K-means добавить случай матрицы расстояний через cos
# и считать оценку на основе многих испытаний,
# в AgglomerativeClustering посмотреть различный варианты счета расстояний

# %%
def get_res(typename, dataset):
    print(typename)

    results = [[rand(0, 3) for i in range(len(dataset))],
               KMeans(n_clusters=4, random_state=42, n_init="auto").fit(dataset),
               DBSCAN(eps=0.3, min_samples=5, metric="euclidean").fit(dataset),
               DBSCAN(eps=0.3, min_samples=5, metric="cosine").fit(dataset),
               AgglomerativeClustering(n_clusters=4).fit(dataset)]

    names = ["Random", "K-means", "DBSCAN(euc)", "DBSCAN(cos)", "AgglomerativeClustering"]
    tab = " " * 7

    for i in range(len(results)):
        if i == 0:
            res = results[i]
        else:
            res = results[i].labels_
        name = names[i]

        acc = metrics.homogeneity_completeness_v_measure(newsgroups_train.target, res)
        print_acc(name, "HCV-measure", acc, tab, next_res=False)

        try:
            acc = metrics.silhouette_score(dataset, res, metric='euclidean')
            print_acc(name, "Silhouette-score(euc)", acc, tab, next_res=True)

            acc = metrics.silhouette_score(dataset, res, metric='cosine')
            print_acc(name, "Silhouette-score(cos)", acc, tab, next_res=True)
        except ValueError:
            print_acc(name, "Silhouette-score", "error 1 cluster", tab, next_res=True)

        acc = metrics.fowlkes_mallows_score(newsgroups_train.target, res)
        print_acc(name, "Fowlkes-Mallows-score", acc, tab, next_res=True)

        if i < len(results) - 1:
            print()

    print("-" * 100)

# %%
def print_acc(name_method, name_metric, acc, ettab, next_res=False):
    tab = ettab

    if not next_res:
        print(f"{tab}{name_method}")
    else:
        print()

    tab += ettab

    if name_metric == "HCV-measure":
        print(f"{tab}HCV-measure")
        tab += ettab

        print(f"{tab}H-score:{tab}{round(acc[0], 3)}")
        print(f"{tab}C-score:{tab}{round(acc[1], 3)}")
        print(f"{tab}V-score:{tab}{round(acc[2], 3)}")
    else:
        try:
            print(f"{tab}{name_metric}:{tab}{round(acc, 3)}")
        except TypeError:
            print(f"{tab}{name_metric}:{tab}{acc}")

# %%
num_reg_exp = r'[-+]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][-+]?\d+)?'
special_sym = ["(", ")", ":", "@", "?", ",", "|", ">", "<", "]", "\'", "{", "/", "^"
               "[", ".", "``", "\'\'", "--", "!", "-", "*", "..", "$", "}", "#", "="]
stop_words = stopwords.words('english') + special_sym


def delete_stopword_and_lemmatize(listw):
    res = []
    for word in listw:
        word = lemmatizer.lemmatize(word.lower())
        if word not in stop_words and re.fullmatch(num_reg_exp, word) is None\
            and not any(sym in word for sym in special_sym):
            res += [word]
    return res

# %%
NOUN_TAG = ['NN', "NNS"]
JJ_TAG = ["JJ", "JJR", "JJS"]
VB_TAG = ["VB", "VBD", "VBG", "VBN", "VBP", "VBZ"]


def only_pos(list_doc, pos_t_cls):
    len_docs = len(list_doc)
    cnt_cls = len(pos_t_cls)
    res = [[] for i in range(cnt_cls)]

    with tqdm(total=len_docs, position=0, leave=True) as pbar:
        for idxd in range(len_docs):

            pbar.set_description(f"Doc: {idxd+1}/{len_docs}")
            pbar.update()

            ndoc = [[] for i in range(cnt_cls)]
            for elem in nltk.pos_tag(list_doc[idxd]):
                for idxpos in range(cnt_cls):
                    if elem[1] in pos_t_cls[idxpos]:
                        ndoc[idxpos] += [elem[0]]

            for idxpos in range(cnt_cls):
                res[idxpos] += [ndoc[idxpos]]
    return tuple(res)

# %%
def get_bow_var(bow, dictn):
    res = []
    for i in range(len(bow)):
        doc = [0 for j in range(len(dictn))]
        for val in bow[i]:
            doc[val[0]] = val[1]

        res += [doc]
    return res


def get_tfidf_var(tfidf, dictn):
    res = []
    for i in range(len(tfidf)):
        doc = [0 for j in range(len(dictn))]
        for val in tfidf[i]:
            doc[val[0]] = val[1]

        res += [doc]
    return res

# %%
def get_lsi(corpus, dictn, num_topics=20):
    lsi_model = models.LsiModel(corpus=corpus, num_topics=num_topics, id2word=dictn)
    lsi_res = []
    for i in range(len(corpus)):
        lsi_res += [[val[1] for val in lsi_model[corpus[i]]]]
    return lsi_res


def get_lda(corpus, dictn, alpha='symmetric', bbeta=None, num_topics=20):
    lda_model = models.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictn, passes=10, alpha=alpha, eta=bbeta)
    lda_res = []
    for i in range(len(corpus)):
        lda_res += [[val[1] for val in lda_model.get_document_topics(corpus[i], minimum_probability=0.0)]]
    return lda_res

# %%
tokenize_data = [delete_stopword_and_lemmatize(nltk.word_tokenize(newsgroups_train.data[i]))
                 for i in range(len(newsgroups_train.data))]

# %%
dictn = corpora.Dictionary(tokenize_data)
dictn.filter_extremes(keep_n=1000)

bow = [dictn.doc2bow(doc) for doc in tokenize_data]

model = TfidfModel(bow)
tfidf = [model[doc] for doc in bow]

# %%
bow_res = {"BoW": get_bow_var(bow, dictn)}
tf_idf_res = {"TF-IDF": get_tfidf_var(tfidf, dictn)}
Lsi_res = {"LSI(ntop=5)": get_lsi(tfidf, dictn, 5),
           "LSI(ntop=20)": get_lsi(tfidf, dictn, 20),
           "LSI(ntop=50)": get_lsi(tfidf, dictn, 50)}

# %%
Lda_res = {"LDA(ntop=5, alpha=symmetric, beta=None)": get_lda(bow, dictn, 'symmetric', None, num_topics=5),
           "LDA(ntop=20, alpha=symmetric, beta=None)": get_lda(bow, dictn, 'symmetric', None, num_topics=20),
           "LDA(ntop=50, alpha=symmetric, beta=None)": get_lda(bow, dictn, 'symmetric', None, num_topics=50),
           "LDA(ntop=20, alpha=0.1, beta=0.1)": get_lda(bow, dictn, 0.1, 0.1, num_topics=20),
           "LDA(ntop=20, alpha=0.5, beta=0.1)": get_lda(bow, dictn, 0.5, 0.1, num_topics=20),
           "LDA(ntop=20, alpha=0.5, beta=0.5)": get_lda(bow, dictn, 0.5, 0.5, num_topics=20),
           "LDA(ntop=20, alpha=2, beta=0.1)": get_lda(bow, dictn, 2, 0.1, num_topics=20),
           "LDA(ntop=20, alpha=2, beta=0.5)": get_lda(bow, dictn, 2, 0.5, num_topics=20),
           "LDA(ntop=20, alpha=0.1, beta=2)": get_lda(bow, dictn, 0.1, 2, num_topics=20)}

# %%
tokenize_data_noun, tokenize_data_noun_jj_vb = only_pos(tokenize_data, [NOUN_TAG, NOUN_TAG + JJ_TAG + VB_TAG])
# Out:
# Doc: 3765/3765: 100%|██████████████████████████████████████████████████████████████| 3765/3765 [01:14<00:00, 50.87it/s]

# %%
dictn_noun, dictn_noun_jj_vb = corpora.Dictionary(tokenize_data_noun), corpora.Dictionary(tokenize_data_noun_jj_vb)
dictn_noun.filter_extremes(keep_n=1000)
dictn_noun_jj_vb.filter_extremes(keep_n=1000)

bow_noun = [dictn_noun.doc2bow(doc) for doc in tokenize_data_noun]
bow_noun_jj_vb = [dictn_noun_jj_vb.doc2bow(doc) for doc in tokenize_data_noun_jj_vb]

model = TfidfModel(bow_noun)
tfidf_noun = [model[doc] for doc in bow_noun]

model = TfidfModel(bow_noun_jj_vb)
tfidf_noun_jj_vb = [model[doc] for doc in bow_noun_jj_vb]

# %%
bow_res.update({"BoW(NOUN)": get_bow_var(bow_noun, dictn_noun),
                "BoW(NOUN_JJ_VB)": get_bow_var(bow_noun_jj_vb, dictn_noun_jj_vb)})
tf_idf_res.update({"TF-IDF(NOUN)": get_tfidf_var(tfidf_noun, dictn_noun),
                   "TF-IDF(NOUN_JJ_VB)": get_tfidf_var(tfidf_noun_jj_vb, dictn_noun_jj_vb)})
Lsi_res.update({"LSI(NOUN, ntop=20)": get_lsi(tfidf_noun, dictn_noun, 20),
                "LSI(NOUN_JJ_VB, ntop=20)": get_lsi(tfidf_noun_jj_vb, dictn_noun_jj_vb, 20)})
Lda_res.update({"LDA(NOUN, ntop=20, alpha=symmetric, beta=None)": get_lda(bow_noun, dictn_noun),
                "LDA(NOUN_JJ_VB, ntop=20, alpha=symmetric, beta=None)": get_lda(bow_noun_jj_vb, dictn_noun_jj_vb)})

# %%
Lda_res.update({"LDA(NOUN, ntop=5, alpha=symmetric, beta=None)": get_lda(bow_noun, dictn_noun, num_topics=5),
                "LDA(NOUN_JJ_VB, ntop=5, alpha=symmetric, beta=None)": get_lda(bow_noun_jj_vb, dictn_noun_jj_vb, num_topics=5)})

# %%
reses = [bow_res, tf_idf_res, Lsi_res, Lda_res]

# %%
for res in reses:
    for key in res.keys():
        get_res(key, res[key])
# Out:
# BoW
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.006
#
#               Silhouette-score(cos):              -0.002
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.01
#                      C-score:                     0.098
#                      V-score:                     0.018
#
#               Silhouette-score(euc):              0.653
#
#               Silhouette-score(cos):              -0.098
#
#               Fowlkes-Mallows-score:              0.49
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.036
#                      C-score:                     0.186
#                      V-score:                     0.061
#
#               Silhouette-score(euc):              -0.288
#
#               Silhouette-score(cos):              -0.134
#
#               Fowlkes-Mallows-score:              0.483
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.002
#                      C-score:                     0.171
#                      V-score:                     0.003
#
#               Silhouette-score(euc):              0.892
#
#               Silhouette-score(cos):              -0.088
#
#               Fowlkes-Mallows-score:              0.501
# ----------------------------------------------------------------------------------------------------
# BoW(NOUN)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.017
#
#               Silhouette-score(cos):              -0.002
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.009
#                      C-score:                     0.176
#                      V-score:                     0.017
#
#               Silhouette-score(euc):              0.706
#
#               Silhouette-score(cos):              -0.069
#
#               Fowlkes-Mallows-score:              0.497
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.076
#                      C-score:                     0.197
#                      V-score:                     0.11
#
#               Silhouette-score(euc):              -0.25
#
#               Silhouette-score(cos):              -0.151
#
#               Fowlkes-Mallows-score:              0.462
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.098
#                      V-score:                     0.003
#
#               Silhouette-score(euc):              0.891
#
#               Silhouette-score(cos):              -0.051
#
#               Fowlkes-Mallows-score:              0.5
# ----------------------------------------------------------------------------------------------------
# BoW(NOUN_JJ_VB)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.021
#
#               Silhouette-score(cos):              -0.002
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.012
#                      C-score:                     0.174
#                      V-score:                     0.022
#
#               Silhouette-score(euc):              0.675
#
#               Silhouette-score(cos):              -0.086
#
#               Fowlkes-Mallows-score:              0.495
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.054
#                      C-score:                     0.193
#                      V-score:                     0.085
#
#               Silhouette-score(euc):              -0.269
#
#               Silhouette-score(cos):              -0.149
#
#               Fowlkes-Mallows-score:              0.473
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.002
#                      C-score:                     0.171
#                      V-score:                     0.003
#
#               Silhouette-score(euc):              0.899
#
#               Silhouette-score(cos):              -0.08
#
#               Fowlkes-Mallows-score:              0.501
# ----------------------------------------------------------------------------------------------------
# TF-IDF
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.001
#
#               Silhouette-score(cos):              -0.001
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.52
#                      C-score:                     0.579
#                      V-score:                     0.548
#
#               Silhouette-score(euc):              0.014
#
#               Silhouette-score(cos):              0.026
#
#               Fowlkes-Mallows-score:              0.6
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.002
#                      C-score:                     0.183
#                      V-score:                     0.004
#
#               Silhouette-score(euc):              0.009
#
#               Silhouette-score(cos):              0.015
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.048
#                      C-score:                     0.19
#                      V-score:                     0.077
#
#               Silhouette-score(euc):              -0.051
#
#               Silhouette-score(cos):              -0.101
#
#               Fowlkes-Mallows-score:              0.476
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.475
#                      C-score:                     0.525
#                      V-score:                     0.499
#
#               Silhouette-score(euc):              0.012
#
#               Silhouette-score(cos):              0.022
#
#               Fowlkes-Mallows-score:              0.561
# ----------------------------------------------------------------------------------------------------
# TF-IDF(NOUN)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.001
#
#               Silhouette-score(cos):              -0.001
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.81
#                      C-score:                     0.81
#                      V-score:                     0.81
#
#               Silhouette-score(euc):              0.018
#
#               Silhouette-score(cos):              0.034
#
#               Fowlkes-Mallows-score:              0.891
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.072
#                      C-score:                     0.188
#                      V-score:                     0.104
#
#               Silhouette-score(euc):              -0.055
#
#               Silhouette-score(cos):              -0.109
#
#               Fowlkes-Mallows-score:              0.466
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.537
#                      C-score:                     0.538
#                      V-score:                     0.538
#
#               Silhouette-score(euc):              0.013
#
#               Silhouette-score(cos):              0.025
#
#               Fowlkes-Mallows-score:              0.674
# ----------------------------------------------------------------------------------------------------
# TF-IDF(NOUN_JJ_VB)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.001
#
#               Silhouette-score(cos):              -0.001
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.582
#                      C-score:                     0.671
#                      V-score:                     0.623
#
#               Silhouette-score(euc):              0.014
#
#               Silhouette-score(cos):              0.026
#
#               Fowlkes-Mallows-score:              0.675
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.002
#                      C-score:                     0.183
#                      V-score:                     0.004
#
#               Silhouette-score(euc):              0.006
#
#               Silhouette-score(cos):              0.01
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.049
#                      C-score:                     0.193
#                      V-score:                     0.078
#
#               Silhouette-score(euc):              -0.052
#
#               Silhouette-score(cos):              -0.103
#
#               Fowlkes-Mallows-score:              0.476
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.574
#                      C-score:                     0.599
#                      V-score:                     0.586
#
#               Silhouette-score(euc):              0.014
#
#               Silhouette-score(cos):              0.027
#
#               Fowlkes-Mallows-score:              0.662
# ----------------------------------------------------------------------------------------------------
# LSI(ntop=5)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.014
#
#               Silhouette-score(cos):              -0.018
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.574
#                      C-score:                     0.683
#                      V-score:                     0.624
#
#               Silhouette-score(euc):              0.381
#
#               Silhouette-score(cos):              0.548
#
#               Fowlkes-Mallows-score:              0.645
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.533
#                      C-score:                     0.66
#                      V-score:                     0.59
#
#               Silhouette-score(euc):              0.369
#
#               Silhouette-score(cos):              0.499
#
#               Fowlkes-Mallows-score:              0.617
# ----------------------------------------------------------------------------------------------------
# LSI(ntop=20)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.004
#
#               Silhouette-score(cos):              -0.007
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.558
#                      C-score:                     0.641
#                      V-score:                     0.597
#
#               Silhouette-score(euc):              0.123
#
#               Silhouette-score(cos):              0.227
#
#               Fowlkes-Mallows-score:              0.656
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.05
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              0.318
#
#               Silhouette-score(cos):              0.18
#
#               Fowlkes-Mallows-score:              0.5
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.445
#                      C-score:                     0.56
#                      V-score:                     0.496
#
#               Silhouette-score(euc):              0.132
#
#               Silhouette-score(cos):              0.176
#
#               Fowlkes-Mallows-score:              0.547
# ----------------------------------------------------------------------------------------------------
# LSI(ntop=50)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.004
#
#               Silhouette-score(cos):              -0.005
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.58
#                      C-score:                     0.64
#                      V-score:                     0.609
#
#               Silhouette-score(euc):              0.056
#
#               Silhouette-score(cos):              0.119
#
#               Fowlkes-Mallows-score:              0.621
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.072
#                      C-score:                     0.115
#                      V-score:                     0.089
#
#               Silhouette-score(euc):              -0.007
#
#               Silhouette-score(cos):              -0.107
#
#               Fowlkes-Mallows-score:              0.399
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.013
#                      V-score:                     0.002
#
#               Silhouette-score(euc):              -0.155
#
#               Silhouette-score(cos):              -0.006
#
#               Fowlkes-Mallows-score:              0.491
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.459
#                      C-score:                     0.561
#                      V-score:                     0.505
#
#               Silhouette-score(euc):              0.067
#
#               Silhouette-score(cos):              0.094
#
#               Fowlkes-Mallows-score:              0.556
# ----------------------------------------------------------------------------------------------------
# LSI(NOUN, ntop=20)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.01
#
#               Silhouette-score(cos):              -0.007
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.538
#                      C-score:                     0.647
#                      V-score:                     0.588
#
#               Silhouette-score(euc):              0.124
#
#               Silhouette-score(cos):              0.209
#
#               Fowlkes-Mallows-score:              0.631
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.12
#                      V-score:                     0.003
#
#               Silhouette-score(euc):              0.377
#
#               Silhouette-score(cos):              0.164
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.635
#                      C-score:                     0.656
#                      V-score:                     0.645
#
#               Silhouette-score(euc):              0.123
#
#               Silhouette-score(cos):              0.24
#
#               Fowlkes-Mallows-score:              0.705
# ----------------------------------------------------------------------------------------------------
# LSI(NOUN_JJ_VB, ntop=20)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.012
#
#               Silhouette-score(cos):              -0.01
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.6
#                      C-score:                     0.673
#                      V-score:                     0.634
#
#               Silhouette-score(euc):              0.136
#
#               Silhouette-score(cos):              0.243
#
#               Fowlkes-Mallows-score:              0.645
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.106
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              0.312
#
#               Silhouette-score(cos):              0.178
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.728
#                      C-score:                     0.734
#                      V-score:                     0.731
#
#               Silhouette-score(euc):              0.123
#
#               Silhouette-score(cos):              0.273
#
#               Fowlkes-Mallows-score:              0.81
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.008999999612569809
#
#               Silhouette-score(cos):              -0.009999999776482582
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.724
#                      C-score:                     0.725
#                      V-score:                     0.724
#
#               Silhouette-score(euc):              0.6389999985694885
#
#               Silhouette-score(cos):              0.7879999876022339
#
#               Fowlkes-Mallows-score:              0.825
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.716
#                      C-score:                     0.718
#                      V-score:                     0.717
#
#               Silhouette-score(euc):              0.625
#
#               Silhouette-score(cos):              0.7680000066757202
#
#               Fowlkes-Mallows-score:              0.824
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.006000000052154064
#
#               Silhouette-score(cos):              -0.008999999612569809
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.349
#                      C-score:                     0.427
#                      V-score:                     0.384
#
#               Silhouette-score(euc):              0.19099999964237213
#
#               Silhouette-score(cos):              0.2939999997615814
#
#               Fowlkes-Mallows-score:              0.504
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.002
#                      C-score:                     0.016
#                      V-score:                     0.003
#
#               Silhouette-score(euc):              -0.08500000089406967
#
#               Silhouette-score(cos):              -0.014000000432133675
#
#               Fowlkes-Mallows-score:              0.487
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.475
#                      C-score:                     0.511
#                      V-score:                     0.492
#
#               Silhouette-score(euc):              0.1940000057220459
#
#               Silhouette-score(cos):              0.27799999713897705
#
#               Fowlkes-Mallows-score:              0.574
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=50, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.004999999888241291
#
#               Silhouette-score(cos):              -0.004999999888241291
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.317
#                      C-score:                     0.527
#                      V-score:                     0.396
#
#               Silhouette-score(euc):              0.03200000151991844
#
#               Silhouette-score(cos):              0.08299999684095383
#
#               Fowlkes-Mallows-score:              0.543
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.438
#                      C-score:                     0.307
#                      V-score:                     0.361
#
#               Silhouette-score(euc):              -0.0949999988079071
#
#               Silhouette-score(cos):              -0.1509999930858612
#
#               Fowlkes-Mallows-score:              0.429
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.007
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.13500000536441803
#
#               Silhouette-score(cos):              0.0
#
#               Fowlkes-Mallows-score:              0.496
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.185
#                      C-score:                     0.324
#                      V-score:                     0.236
#
#               Silhouette-score(euc):              0.08699999749660492
#
#               Silhouette-score(cos):              0.11599999666213989
#
#               Fowlkes-Mallows-score:              0.441
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=0.1, beta=0.1)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.006000000052154064
#
#               Silhouette-score(cos):              -0.00800000037997961
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.515
#                      C-score:                     0.547
#                      V-score:                     0.531
#
#               Silhouette-score(euc):              0.1940000057220459
#
#               Silhouette-score(cos):              0.2930000126361847
#
#               Fowlkes-Mallows-score:              0.61
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.003
#                      C-score:                     0.031
#                      V-score:                     0.006
#
#               Silhouette-score(euc):              -0.12800000607967377
#
#               Silhouette-score(cos):              -0.09399999678134918
#
#               Fowlkes-Mallows-score:              0.487
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.345
#                      C-score:                     0.44
#                      V-score:                     0.387
#
#               Silhouette-score(euc):              0.1599999964237213
#
#               Silhouette-score(cos):              0.19499999284744263
#
#               Fowlkes-Mallows-score:              0.476
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=0.5, beta=0.1)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.004999999888241291
#
#               Silhouette-score(cos):              -0.007000000216066837
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.397
#                      C-score:                     0.454
#                      V-score:                     0.424
#
#               Silhouette-score(euc):              0.11599999666213989
#
#               Silhouette-score(cos):              0.18400000035762787
#
#               Fowlkes-Mallows-score:              0.494
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.51
#                      C-score:                     0.579
#                      V-score:                     0.542
#
#               Silhouette-score(euc):              0.13500000536441803
#
#               Silhouette-score(cos):              0.2150000035762787
#
#               Fowlkes-Mallows-score:              0.575
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=0.5, beta=0.5)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.004000000189989805
#
#               Silhouette-score(cos):              -0.007000000216066837
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.504
#                      C-score:                     0.572
#                      V-score:                     0.536
#
#               Silhouette-score(euc):              0.11900000274181366
#
#               Silhouette-score(cos):              0.22200000286102295
#
#               Fowlkes-Mallows-score:              0.625
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.098
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              0.3019999861717224
#
#               Silhouette-score(cos):              0.15299999713897705
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.511
#                      C-score:                     0.559
#                      V-score:                     0.534
#
#               Silhouette-score(euc):              0.14100000262260437
#
#               Silhouette-score(cos):              0.2280000001192093
#
#               Fowlkes-Mallows-score:              0.581
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=2, beta=0.1)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.009999999776482582
#
#               Silhouette-score(cos):              -0.014999999664723873
#
#               Fowlkes-Mallows-score:              0.25
#
#        K-means
#               HCV-measure
#                      H-score:                     0.387
#                      C-score:                     0.512
#                      V-score:                     0.441
#
#               Silhouette-score(euc):              0.3529999852180481
#
#               Silhouette-score(cos):              0.44699999690055847
#
#               Fowlkes-Mallows-score:              0.475
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.068
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              0.6629999876022339
#
#               Silhouette-score(cos):              0.5619999766349792
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.375
#                      C-score:                     0.529
#                      V-score:                     0.439
#
#               Silhouette-score(euc):              0.2840000092983246
#
#               Silhouette-score(cos):              0.34700000286102295
#
#               Fowlkes-Mallows-score:              0.502
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=2, beta=0.5)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.01600000075995922
#
#               Silhouette-score(cos):              -0.017000000923871994
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.382
#                      C-score:                     0.508
#                      V-score:                     0.436
#
#               Silhouette-score(euc):              0.35600000619888306
#
#               Silhouette-score(cos):              0.44600000977516174
#
#               Fowlkes-Mallows-score:              0.472
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.104
#                      V-score:                     0.002
#
#               Silhouette-score(euc):              0.6759999990463257
#
#               Silhouette-score(cos):              0.5640000104904175
#
#               Fowlkes-Mallows-score:              0.501
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.457
#                      C-score:                     0.557
#                      V-score:                     0.502
#
#               Silhouette-score(euc):              0.3319999873638153
#
#               Silhouette-score(cos):              0.44699999690055847
#
#               Fowlkes-Mallows-score:              0.515
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=0.1, beta=2)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.004999999888241291
#
#               Silhouette-score(cos):              -0.007000000216066837
#
#               Fowlkes-Mallows-score:              0.25
#
#        K-means
#               HCV-measure
#                      H-score:                     0.408
#                      C-score:                     0.511
#                      V-score:                     0.453
#
#               Silhouette-score(euc):              0.20800000429153442
#
#               Silhouette-score(cos):              0.2750000059604645
#
#               Fowlkes-Mallows-score:              0.508
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.005
#                      C-score:                     0.042
#                      V-score:                     0.008
#
#               Silhouette-score(euc):              -0.1469999998807907
#
#               Silhouette-score(cos):              -0.10400000214576721
#
#               Fowlkes-Mallows-score:              0.486
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.28
#                      C-score:                     0.368
#                      V-score:                     0.318
#
#               Silhouette-score(euc):              0.18799999356269836
#
#               Silhouette-score(cos):              0.2370000034570694
#
#               Fowlkes-Mallows-score:              0.441
# ----------------------------------------------------------------------------------------------------
# LDA(NOUN, ntop=20, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.0
#                      V-score:                     0.0
#
#               Silhouette-score(euc):              -0.004999999888241291
#
#               Silhouette-score(cos):              -0.007000000216066837
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.308
#                      C-score:                     0.432
#                      V-score:                     0.36
#
#               Silhouette-score(euc):              0.08699999749660492
#
#               Silhouette-score(cos):              0.14800000190734863
#
#               Fowlkes-Mallows-score:              0.473
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.002
#                      C-score:                     0.017
#                      V-score:                     0.004
#
#               Silhouette-score(euc):              -0.10000000149011612
#
#               Silhouette-score(cos):              -0.03099999949336052
#
#               Fowlkes-Mallows-score:              0.483
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.476
#                      C-score:                     0.538
#                      V-score:                     0.505
#
#               Silhouette-score(euc):              0.17000000178813934
#
#               Silhouette-score(cos):              0.23800000548362732
#
#               Fowlkes-Mallows-score:              0.573
# ----------------------------------------------------------------------------------------------------
# LDA(NOUN_JJ_VB, ntop=20, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.004999999888241291
#
#               Silhouette-score(cos):              -0.007000000216066837
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.38
#                      C-score:                     0.471
#                      V-score:                     0.421
#
#               Silhouette-score(euc):              0.10199999809265137
#
#               Silhouette-score(cos):              0.20399999618530273
#
#               Fowlkes-Mallows-score:              0.56
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     0.005
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.07599999755620956
#
#               Silhouette-score(cos):              0.014999999664723873
#
#               Fowlkes-Mallows-score:              0.486
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.32
#                      C-score:                     0.432
#                      V-score:                     0.368
#
#               Silhouette-score(euc):              0.17800000309944153
#
#               Silhouette-score(cos):              0.2280000001192093
#
#               Fowlkes-Mallows-score:              0.441
# ----------------------------------------------------------------------------------------------------
# LDA(NOUN, ntop=5, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.012000000104308128
#
#               Silhouette-score(cos):              -0.014999999664723873
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.743
#                      C-score:                     0.741
#                      V-score:                     0.742
#
#               Silhouette-score(euc):              0.6520000100135803
#
#               Silhouette-score(cos):              0.7910000085830688
#
#               Fowlkes-Mallows-score:              0.841
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.734
#                      C-score:                     0.732
#                      V-score:                     0.733
#
#               Silhouette-score(euc):              0.6359999775886536
#
#               Silhouette-score(cos):              0.7670000195503235
#
#               Fowlkes-Mallows-score:              0.839
# ----------------------------------------------------------------------------------------------------
# LDA(NOUN_JJ_VB, ntop=5, alpha=symmetric, beta=None)
#        Random
#               HCV-measure
#                      H-score:                     0.001
#                      C-score:                     0.001
#                      V-score:                     0.001
#
#               Silhouette-score(euc):              -0.010999999940395355
#
#               Silhouette-score(cos):              -0.014000000432133675
#
#               Fowlkes-Mallows-score:              0.251
#
#        K-means
#               HCV-measure
#                      H-score:                     0.542
#                      C-score:                     0.586
#                      V-score:                     0.563
#
#               Silhouette-score(euc):              0.5249999761581421
#
#               Silhouette-score(cos):              0.6840000152587891
#
#               Fowlkes-Mallows-score:              0.632
#
#        DBSCAN(euc)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        DBSCAN(cos)
#               HCV-measure
#                      H-score:                     0.0
#                      C-score:                     1.0
#                      V-score:                     0.0
#
#               Silhouette-score:              error 1 cluster
#
#               Fowlkes-Mallows-score:              0.502
#
#        AgglomerativeClustering
#               HCV-measure
#                      H-score:                     0.545
#                      C-score:                     0.57
#                      V-score:                     0.557
#
#               Silhouette-score(euc):              0.5299999713897705
#
#               Silhouette-score(cos):              0.675000011920929
#
#               Fowlkes-Mallows-score:              0.627
# ----------------------------------------------------------------------------------------------------
