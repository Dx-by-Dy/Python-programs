# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn import metrics
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn import preprocessing

import torch
from transformers import BertTokenizer, BertModel

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
from gensim.models import TfidfModel
import re

import numpy as np

from tqdm import tqdm
from random import randint as rand

lemmatizer = WordNetLemmatizer()
newsgroups_train = fetch_20newsgroups(subset='all',
                                      categories=['alt.atheism',
                                                  # 'comp.graphics',
                                                  # 'comp.os.ms-windows.misc',
                                                  'comp.sys.ibm.pc.hardware',
                                                  # 'comp.sys.mac.hardware',
                                                  # 'comp.windows.x',
                                                  # 'misc.forsale',
                                                  'rec.autos',
                                                  # 'rec.motorcycles',
                                                  'rec.sport.baseball'],
                                      remove=("header",))

# %%
def get_acc(target, result, dataset):
    res = list(map(lambda x: round(x, 3), metrics.homogeneity_completeness_v_measure(target, result)))
    try:
        res += [round(metrics.silhouette_score(dataset, result, metric='euclidean'), 3)]
        res += [round(metrics.silhouette_score(dataset, result, metric='cosine'), 3)]
    except ValueError:
        res += [None, None]
    res += [round(metrics.adjusted_rand_score(target, result), 3)]
    return res

# %%
def print_acc(name_method, acc, ettab, tol=None):
    tab = ettab
    names = ["H-score", "C-score", "V-score", "Silhouette-score(euc)", "Silhouette-score(cos)", "Adjusted-rand-score"]

    if tol is None:
        tol = ["" for i in range(len(acc))]
    else:
        tol = [f" ± {tol[i]}" for i in range(len(acc))]

    print(f"{tab}{name_method}")
    tab += ettab

    for i in range(len(acc)):
        offset = 50 - len(tab) - len(names[i]) - 1
        print(f"{tab}{names[i]}:{' ' * offset}{acc[i]}{tol[i]}")

# %%
class Random_clust():
    def __init__(self):
        self.labels_ = []

    def fit(self, dataset, n_cls=4):
        self.labels_ = [rand(0, n_cls - 1) for i in range(len(dataset))]
        return self

# %%
def get_res(typename, dataset):
    print(typename)

    methods = {"Random": Random_clust(),
               "K-means(euc)": KMeans(n_clusters=4, n_init="auto"),
               "K-means(cos)": KMeans(n_clusters=4, n_init="auto"),
               "DBSCAN(euc)": DBSCAN(eps=0.3, min_samples=5, metric="euclidean"),
               "DBSCAN(cos)": DBSCAN(eps=0.3, min_samples=5, metric="cosine"),
               "AgglomerativeClustering(euc, ward)": AgglomerativeClustering(n_clusters=4, metric="euclidean"),
               "AgglomerativeClustering(cos, complete)": AgglomerativeClustering(n_clusters=4, metric="cosine", linkage="complete")}

    tab = " " * 7
    kmeans_it = 10
    norm_dataset = preprocessing.normalize(dataset)

    for key in methods.keys():

        method = methods[key]

        if key == "K-means(euc)" or key == "K-means(cos)":
            accs = []
            for i in range(kmeans_it):
                if key == "K-means(cos)":
                    accs += [get_acc(newsgroups_train.target, method.fit(norm_dataset).labels_, norm_dataset)]
                else:
                    accs += [get_acc(newsgroups_train.target, method.fit(dataset).labels_, dataset)]
            acc, tol = [], []
            for i in range(len(accs[0])):
                acc += [round(np.mean([accs[j][i] for j in range(kmeans_it)]), 3)]
                tol += [round(np.std([accs[j][i] for j in range(kmeans_it)]), 3)]
            print_acc(key, acc, tab, tol)
        else:
            acc = get_acc(newsgroups_train.target, method.fit(dataset).labels_, dataset)
            print_acc(key, acc, tab)

        if key != list(methods.keys())[-1]:
            print()

    print("-" * 100)

# %%
num_reg_exp = r'[-+]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][-+]?\d+)?'
special_sym = ["(", ")", ":", "@", "?", ",", "|", ">", "<", "]", "\'", "{", "/", "^"
               "[", ".", "``", "\'\'", "--", "!", "-", "*", "..", "$", "}", "#", "="]
stop_words = stopwords.words('english') + special_sym


def delete_stopword_and_lemmatize(listw):
    res = []
    for word in listw:
        word = lemmatizer.lemmatize(word.lower())
        if word not in stop_words and re.fullmatch(num_reg_exp, word) is None\
            and not any(sym in word for sym in special_sym):
            res += [word]
    return res

# %%
NOUN_TAG = ['NN', "NNS"]
JJ_TAG = ["JJ", "JJR", "JJS"]
VB_TAG = ["VB", "VBD", "VBG", "VBN", "VBP", "VBZ"]


def only_pos(list_doc, pos_t_cls):
    len_docs = len(list_doc)
    cnt_cls = len(pos_t_cls)
    res = [[] for i in range(cnt_cls)]

    with tqdm(total=len_docs, position=0, leave=True) as pbar:
        for idxd in range(len_docs):

            pbar.set_description(f"Doc: {idxd+1}/{len_docs}")
            pbar.update()

            ndoc = [[] for i in range(cnt_cls)]
            for elem in nltk.pos_tag(list_doc[idxd]):
                for idxpos in range(cnt_cls):
                    if elem[1] in pos_t_cls[idxpos]:
                        ndoc[idxpos] += [elem[0]]

            for idxpos in range(cnt_cls):
                res[idxpos] += [ndoc[idxpos]]
    return tuple(res)

# %%
def get_bow_var(bow, dictn):
    res = []
    for i in range(len(bow)):
        doc = [0 for j in range(len(dictn))]
        for val in bow[i]:
            doc[val[0]] = val[1]

        res += [doc]
    return res


def get_tfidf_var(tfidf, dictn):
    res = []
    for i in range(len(tfidf)):
        doc = [0 for j in range(len(dictn))]
        for val in tfidf[i]:
            doc[val[0]] = val[1]

        res += [doc]
    return res

# %%
def get_lsi(corpus, dictn, num_topics=20):
    lsi_model = models.LsiModel(corpus=corpus, num_topics=num_topics, id2word=dictn)
    lsi_res = []
    for i in range(len(corpus)):
        lsi_res += [[val[1] for val in lsi_model[corpus[i]]]]
    return lsi_res


def get_lda(corpus, dictn, alpha='symmetric', bbeta=None, num_topics=20):
    lda_model = models.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictn, passes=10, alpha=alpha, eta=bbeta)
    lda_res = []
    for i in range(len(corpus)):
        lda_res += [[val[1] for val in lda_model.get_document_topics(corpus[i], minimum_probability=0.0)]]
    return lda_res

# %%
tokenize_data = [delete_stopword_and_lemmatize(nltk.word_tokenize(newsgroups_train.data[i]))
                 for i in range(len(newsgroups_train.data))]

# %%
dictn = corpora.Dictionary(tokenize_data)
dictn.filter_extremes(keep_n=1000)

bow = [dictn.doc2bow(doc) for doc in tokenize_data]

model = TfidfModel(bow)
tfidf = [model[doc] for doc in bow]

# %%
bow_res = {"BoW": get_bow_var(bow, dictn)}
tf_idf_res = {"TF-IDF": get_tfidf_var(tfidf, dictn)}
Lsi_res = {"LSI(ntop=5)": get_lsi(tfidf, dictn, 5),
           "LSI(ntop=20)": get_lsi(tfidf, dictn, 20),
           "LSI(ntop=50)": get_lsi(tfidf, dictn, 50)}

# %%
Lda_res = {"LDA(ntop=5, alpha=symmetric, beta=None)": get_lda(bow, dictn, 'symmetric', None, num_topics=5),
           "LDA(ntop=20, alpha=symmetric, beta=None)": get_lda(bow, dictn, 'symmetric', None, num_topics=20),
           "LDA(ntop=50, alpha=symmetric, beta=None)": get_lda(bow, dictn, 'symmetric', None, num_topics=50),
           "LDA(ntop=5, alpha=0.1, beta=0.1)": get_lda(bow, dictn, 0.1, 0.1, num_topics=5),
           "LDA(ntop=5, alpha=0.5, beta=0.1)": get_lda(bow, dictn, 0.5, 0.1, num_topics=5),
           "LDA(ntop=5, alpha=0.5, beta=0.5)": get_lda(bow, dictn, 0.5, 0.5, num_topics=5),
           "LDA(ntop=5, alpha=2, beta=0.1)": get_lda(bow, dictn, 2, 0.1, num_topics=5),
           "LDA(ntop=5, alpha=2, beta=0.5)": get_lda(bow, dictn, 2, 0.5, num_topics=5),
           "LDA(ntop=5, alpha=0.1, beta=2)": get_lda(bow, dictn, 0.1, 2, num_topics=5)}

# %%
tokenize_data_noun, tokenize_data_noun_jj_vb = only_pos(tokenize_data, [NOUN_TAG, NOUN_TAG + JJ_TAG + VB_TAG])
# Out:
# Doc: 3765/3765: 100%|██████████████████████████████████████████████████████████████| 3765/3765 [01:09<00:00, 53.80it/s]

# %%
dictn_noun, dictn_noun_jj_vb = corpora.Dictionary(tokenize_data_noun), corpora.Dictionary(tokenize_data_noun_jj_vb)
dictn_noun.filter_extremes(keep_n=1000)
dictn_noun_jj_vb.filter_extremes(keep_n=1000)

bow_noun = [dictn_noun.doc2bow(doc) for doc in tokenize_data_noun]
bow_noun_jj_vb = [dictn_noun_jj_vb.doc2bow(doc) for doc in tokenize_data_noun_jj_vb]

model = TfidfModel(bow_noun)
tfidf_noun = [model[doc] for doc in bow_noun]

model = TfidfModel(bow_noun_jj_vb)
tfidf_noun_jj_vb = [model[doc] for doc in bow_noun_jj_vb]

# %%
bow_res.update({"BoW(NOUN)": get_bow_var(bow_noun, dictn_noun),
                "BoW(NOUN_JJ_VB)": get_bow_var(bow_noun_jj_vb, dictn_noun_jj_vb)})
tf_idf_res.update({"TF-IDF(NOUN)": get_tfidf_var(tfidf_noun, dictn_noun),
                   "TF-IDF(NOUN_JJ_VB)": get_tfidf_var(tfidf_noun_jj_vb, dictn_noun_jj_vb)})
Lsi_res.update({"LSI(NOUN, ntop=5)": get_lsi(tfidf_noun, dictn_noun, 5),
                "LSI(NOUN_JJ_VB, ntop=5)": get_lsi(tfidf_noun_jj_vb, dictn_noun_jj_vb, 5)})
Lda_res.update({"LDA(NOUN, ntop=5, alpha=symmetric, beta=None)": get_lda(bow_noun, dictn_noun, num_topics=5),
                "LDA(NOUN_JJ_VB, ntop=5, alpha=symmetric, beta=None)": get_lda(bow_noun_jj_vb, dictn_noun_jj_vb, num_topics=5)})

# %%
tokenizer_bert = BertTokenizer.from_pretrained("bert-base-uncased")
model_bert = BertModel.from_pretrained("bert-base-uncased")
preproc_data_bert = [tokenizer_bert(" ".join(tokenize_data[i]), padding=True, truncation=True, return_tensors="pt")
                     for i in range(len(tokenize_data))]

# %%
with torch.no_grad():
    vec_data_bert = []
    len_docs = len(tokenize_data)

    with tqdm(total=len_docs, position=0, leave=True) as pbar:
        for idxdoc in range(len_docs):

            pbar.set_description(f"Doc: {idxdoc+1}/{len_docs}")
            pbar.update()

            vec_data_bert += [model_bert(**preproc_data_bert[idxdoc]).last_hidden_state[:, 0, :].tolist()[0]]

bert_res = {"Bert-model": vec_data_bert}
# Out:
# Doc: 3765/3765: 100%|██████████████████████████████████████████████████████████████| 3765/3765 [26:00<00:00,  2.41it/s]

# %%
reses = [bow_res, tf_idf_res, Lsi_res, Lda_res, bert_res]

# %%
for res in reses:
    for key in res.keys():
        get_res(key, res[key])
# Out:
# BoW
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.014
#               Silhouette-score(cos):              -0.002
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.007 ± 0.004
#               C-score:                            0.095 ± 0.033
#               V-score:                            0.012 ± 0.007
#               Silhouette-score(euc):              0.698 ± 0.132
#               Silhouette-score(cos):              -0.069 ± 0.012
#               Adjusted-rand-score:                0.003 ± 0.002
#
#        K-means(cos)
#               H-score:                            0.385 ± 0.078
#               C-score:                            0.423 ± 0.067
#               V-score:                            0.403 ± 0.073
#               Silhouette-score(euc):              0.015 ± 0.001
#               Silhouette-score(cos):              0.029 ± 0.003
#               Adjusted-rand-score:                0.309 ± 0.115
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.036
#               C-score:                            0.186
#               V-score:                            0.061
#               Silhouette-score(euc):              -0.288
#               Silhouette-score(cos):              -0.134
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.002
#               C-score:                            0.171
#               V-score:                            0.003
#               Silhouette-score(euc):              0.892
#               Silhouette-score(cos):              -0.088
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.004
#               C-score:                            0.037
#               V-score:                            0.007
#               Silhouette-score(euc):              -0.085
#               Silhouette-score(cos):              -0.038
#               Adjusted-rand-score:                0.001
# ----------------------------------------------------------------------------------------------------
# BoW(NOUN)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.013
#               Silhouette-score(cos):              -0.002
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.01 ± 0.013
#               C-score:                            0.152 ± 0.073
#               V-score:                            0.019 ± 0.023
#               Silhouette-score(euc):              0.688 ± 0.206
#               Silhouette-score(cos):              -0.053 ± 0.02
#               Adjusted-rand-score:                0.002 ± 0.002
#
#        K-means(cos)
#               H-score:                            0.478 ± 0.023
#               C-score:                            0.517 ± 0.012
#               V-score:                            0.496 ± 0.017
#               Silhouette-score(euc):              0.025 ± 0.0
#               Silhouette-score(cos):              0.047 ± 0.001
#               Adjusted-rand-score:                0.394 ± 0.069
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.076
#               C-score:                            0.197
#               V-score:                            0.11
#               Silhouette-score(euc):              -0.25
#               Silhouette-score(cos):              -0.151
#               Adjusted-rand-score:                -0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.001
#               C-score:                            0.098
#               V-score:                            0.003
#               Silhouette-score(euc):              0.891
#               Silhouette-score(cos):              -0.051
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.007
#               C-score:                            0.051
#               V-score:                            0.013
#               Silhouette-score(euc):              -0.225
#               Silhouette-score(cos):              -0.028
#               Adjusted-rand-score:                0.002
# ----------------------------------------------------------------------------------------------------
# BoW(NOUN_JJ_VB)
#        Random
#               H-score:                            0.0
#               C-score:                            0.0
#               V-score:                            0.0
#               Silhouette-score(euc):              -0.012
#               Silhouette-score(cos):              -0.002
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.006 ± 0.004
#               C-score:                            0.15 ± 0.043
#               V-score:                            0.011 ± 0.007
#               Silhouette-score(euc):              0.763 ± 0.117
#               Silhouette-score(cos):              -0.071 ± 0.014
#               Adjusted-rand-score:                0.002 ± 0.002
#
#        K-means(cos)
#               H-score:                            0.487 ± 0.076
#               C-score:                            0.531 ± 0.07
#               V-score:                            0.507 ± 0.073
#               Silhouette-score(euc):              0.02 ± 0.001
#               Silhouette-score(cos):              0.037 ± 0.003
#               Adjusted-rand-score:                0.417 ± 0.112
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.054
#               C-score:                            0.193
#               V-score:                            0.085
#               Silhouette-score(euc):              -0.269
#               Silhouette-score(cos):              -0.149
#               Adjusted-rand-score:                -0.001
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.002
#               C-score:                            0.171
#               V-score:                            0.003
#               Silhouette-score(euc):              0.899
#               Silhouette-score(cos):              -0.08
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.009
#               C-score:                            0.109
#               V-score:                            0.017
#               Silhouette-score(euc):              -0.246
#               Silhouette-score(cos):              -0.019
#               Adjusted-rand-score:                -0.0
# ----------------------------------------------------------------------------------------------------
# TF-IDF
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.001
#               Silhouette-score(cos):              -0.001
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.715 ± 0.054
#               C-score:                            0.737 ± 0.037
#               V-score:                            0.726 ± 0.046
#               Silhouette-score(euc):              0.017 ± 0.001
#               Silhouette-score(cos):              0.032 ± 0.002
#               Adjusted-rand-score:                0.69 ± 0.069
#
#        K-means(cos)
#               H-score:                            0.668 ± 0.13
#               C-score:                            0.72 ± 0.061
#               V-score:                            0.69 ± 0.104
#               Silhouette-score(euc):              0.016 ± 0.002
#               Silhouette-score(cos):              0.031 ± 0.004
#               Adjusted-rand-score:                0.625 ± 0.164
#
#        DBSCAN(euc)
#               H-score:                            0.002
#               C-score:                            0.183
#               V-score:                            0.004
#               Silhouette-score(euc):              0.009
#               Silhouette-score(cos):              0.015
#               Adjusted-rand-score:                -0.0
#
#        DBSCAN(cos)
#               H-score:                            0.048
#               C-score:                            0.19
#               V-score:                            0.077
#               Silhouette-score(euc):              -0.051
#               Silhouette-score(cos):              -0.101
#               Adjusted-rand-score:                -0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.475
#               C-score:                            0.525
#               V-score:                            0.499
#               Silhouette-score(euc):              0.012
#               Silhouette-score(cos):              0.022
#               Adjusted-rand-score:                0.379
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.026
#               C-score:                            0.224
#               V-score:                            0.046
#               Silhouette-score(euc):              -0.004
#               Silhouette-score(cos):              -0.009
#               Adjusted-rand-score:                0.001
# ----------------------------------------------------------------------------------------------------
# TF-IDF(NOUN)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.001
#               Silhouette-score(cos):              -0.001
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.746 ± 0.085
#               C-score:                            0.77 ± 0.051
#               V-score:                            0.757 ± 0.069
#               Silhouette-score(euc):              0.017 ± 0.002
#               Silhouette-score(cos):              0.032 ± 0.004
#               Adjusted-rand-score:                0.736 ± 0.138
#
#        K-means(cos)
#               H-score:                            0.678 ± 0.122
#               C-score:                            0.725 ± 0.085
#               V-score:                            0.699 ± 0.103
#               Silhouette-score(euc):              0.016 ± 0.002
#               Silhouette-score(cos):              0.03 ± 0.004
#               Adjusted-rand-score:                0.646 ± 0.183
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.072
#               C-score:                            0.188
#               V-score:                            0.104
#               Silhouette-score(euc):              -0.055
#               Silhouette-score(cos):              -0.109
#               Adjusted-rand-score:                0.002
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.537
#               C-score:                            0.538
#               V-score:                            0.538
#               Silhouette-score(euc):              0.013
#               Silhouette-score(cos):              0.025
#               Adjusted-rand-score:                0.564
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.003
#               C-score:                            0.079
#               V-score:                            0.006
#               Silhouette-score(euc):              -0.005
#               Silhouette-score(cos):              -0.011
#               Adjusted-rand-score:                -0.0
# ----------------------------------------------------------------------------------------------------
# TF-IDF(NOUN_JJ_VB)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.001
#               Silhouette-score(cos):              -0.001
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.725 ± 0.079
#               C-score:                            0.756 ± 0.045
#               V-score:                            0.74 ± 0.063
#               Silhouette-score(euc):              0.017 ± 0.001
#               Silhouette-score(cos):              0.033 ± 0.002
#               Adjusted-rand-score:                0.703 ± 0.118
#
#        K-means(cos)
#               H-score:                            0.755 ± 0.084
#               C-score:                            0.781 ± 0.046
#               V-score:                            0.767 ± 0.067
#               Silhouette-score(euc):              0.017 ± 0.001
#               Silhouette-score(cos):              0.033 ± 0.003
#               Adjusted-rand-score:                0.763 ± 0.121
#
#        DBSCAN(euc)
#               H-score:                            0.002
#               C-score:                            0.183
#               V-score:                            0.004
#               Silhouette-score(euc):              0.006
#               Silhouette-score(cos):              0.01
#               Adjusted-rand-score:                -0.0
#
#        DBSCAN(cos)
#               H-score:                            0.049
#               C-score:                            0.193
#               V-score:                            0.078
#               Silhouette-score(euc):              -0.052
#               Silhouette-score(cos):              -0.103
#               Adjusted-rand-score:                -0.001
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.574
#               C-score:                            0.599
#               V-score:                            0.586
#               Silhouette-score(euc):              0.014
#               Silhouette-score(cos):              0.027
#               Adjusted-rand-score:                0.536
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.005
#               C-score:                            0.116
#               V-score:                            0.01
#               Silhouette-score(euc):              -0.008
#               Silhouette-score(cos):              -0.017
#               Adjusted-rand-score:                -0.0
# ----------------------------------------------------------------------------------------------------
# LSI(ntop=5)
#        Random
#               H-score:                            0.0
#               C-score:                            0.0
#               V-score:                            0.0
#               Silhouette-score(euc):              -0.012
#               Silhouette-score(cos):              -0.015
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.604 ± 0.07
#               C-score:                            0.68 ± 0.036
#               V-score:                            0.639 ± 0.055
#               Silhouette-score(euc):              0.361 ± 0.015
#               Silhouette-score(cos):              0.536 ± 0.049
#               Adjusted-rand-score:                0.519 ± 0.096
#
#        K-means(cos)
#               H-score:                            0.781 ± 0.067
#               C-score:                            0.789 ± 0.045
#               V-score:                            0.785 ± 0.057
#               Silhouette-score(euc):              0.505 ± 0.027
#               Silhouette-score(cos):              0.672 ± 0.038
#               Adjusted-rand-score:                0.822 ± 0.096
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.574
#               C-score:                            0.683
#               V-score:                            0.624
#               Silhouette-score(euc):              0.368
#               Silhouette-score(cos):              0.535
#               Adjusted-rand-score:                0.498
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.626
#               C-score:                            0.628
#               V-score:                            0.627
#               Silhouette-score(euc):              0.309
#               Silhouette-score(cos):              0.561
#               Adjusted-rand-score:                0.61
# ----------------------------------------------------------------------------------------------------
# LSI(ntop=20)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.006
#               Silhouette-score(cos):              -0.008
#               Adjusted-rand-score:                0.0
#
#        K-means(euc)
#               H-score:                            0.557 ± 0.054
#               C-score:                            0.649 ± 0.03
#               V-score:                            0.598 ± 0.042
#               Silhouette-score(euc):              0.133 ± 0.013
#               Silhouette-score(cos):              0.224 ± 0.024
#               Adjusted-rand-score:                0.446 ± 0.068
#
#        K-means(cos)
#               H-score:                            0.726 ± 0.088
#               C-score:                            0.742 ± 0.066
#               V-score:                            0.734 ± 0.077
#               Silhouette-score(euc):              0.167 ± 0.019
#               Silhouette-score(cos):              0.266 ± 0.031
#               Adjusted-rand-score:                0.743 ± 0.129
#
#        DBSCAN(euc)
#               H-score:                            0.001
#               C-score:                            0.051
#               V-score:                            0.001
#               Silhouette-score(euc):              0.323
#               Silhouette-score(cos):              0.181
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.412
#               C-score:                            0.554
#               V-score:                            0.473
#               Silhouette-score(euc):              0.135
#               Silhouette-score(cos):              0.154
#               Adjusted-rand-score:                0.282
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.312
#               C-score:                            0.318
#               V-score:                            0.315
#               Silhouette-score(euc):              0.039
#               Silhouette-score(cos):              0.117
#               Adjusted-rand-score:                0.286
# ----------------------------------------------------------------------------------------------------
# LSI(ntop=50)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.002
#               Silhouette-score(cos):              -0.005
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.525 ± 0.086
#               C-score:                            0.65 ± 0.049
#               V-score:                            0.579 ± 0.071
#               Silhouette-score(euc):              0.067 ± 0.01
#               Silhouette-score(cos):              0.113 ± 0.011
#               Adjusted-rand-score:                0.439 ± 0.098
#
#        K-means(cos)
#               H-score:                            0.755 ± 0.012
#               C-score:                            0.759 ± 0.01
#               V-score:                            0.757 ± 0.011
#               Silhouette-score(euc):              0.08 ± 0.001
#               Silhouette-score(cos):              0.14 ± 0.002
#               Adjusted-rand-score:                0.78 ± 0.018
#
#        DBSCAN(euc)
#               H-score:                            0.067
#               C-score:                            0.111
#               V-score:                            0.084
#               Silhouette-score(euc):              -0.002
#               Silhouette-score(cos):              -0.123
#               Adjusted-rand-score:                0.011
#
#        DBSCAN(cos)
#               H-score:                            0.001
#               C-score:                            0.015
#               V-score:                            0.002
#               Silhouette-score(euc):              -0.152
#               Silhouette-score(cos):              -0.011
#               Adjusted-rand-score:                -0.001
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.488
#               C-score:                            0.59
#               V-score:                            0.534
#               Silhouette-score(euc):              0.067
#               Silhouette-score(cos):              0.106
#               Adjusted-rand-score:                0.385
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.096
#               C-score:                            0.119
#               V-score:                            0.106
#               Silhouette-score(euc):              0.016
#               Silhouette-score(cos):              0.021
#               Adjusted-rand-score:                0.088
# ----------------------------------------------------------------------------------------------------
# LSI(NOUN, ntop=5)
#        Random
#               H-score:                            0.002
#               C-score:                            0.002
#               V-score:                            0.002
#               Silhouette-score(euc):              -0.013
#               Silhouette-score(cos):              -0.02
#               Adjusted-rand-score:                0.001
#
#        K-means(euc)
#               H-score:                            0.702 ± 0.118
#               C-score:                            0.741 ± 0.075
#               V-score:                            0.72 ± 0.098
#               Silhouette-score(euc):              0.368 ± 0.034
#               Silhouette-score(cos):              0.619 ± 0.118
#               Adjusted-rand-score:                0.693 ± 0.187
#
#        K-means(cos)
#               H-score:                            0.783 ± 0.058
#               C-score:                            0.79 ± 0.037
#               V-score:                            0.786 ± 0.048
#               Silhouette-score(euc):              0.528 ± 0.037
#               Silhouette-score(cos):              0.701 ± 0.053
#               Adjusted-rand-score:                0.821 ± 0.086
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.437
#               C-score:                            0.561
#               V-score:                            0.491
#               Silhouette-score(euc):              0.291
#               Silhouette-score(cos):              0.292
#               Adjusted-rand-score:                0.305
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.613
#               C-score:                            0.626
#               V-score:                            0.619
#               Silhouette-score(euc):              0.295
#               Silhouette-score(cos):              0.551
#               Adjusted-rand-score:                0.587
# ----------------------------------------------------------------------------------------------------
# LSI(NOUN_JJ_VB, ntop=5)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.013
#               Silhouette-score(cos):              -0.018
#               Adjusted-rand-score:                0.0
#
#        K-means(euc)
#               H-score:                            0.694 ± 0.09
#               C-score:                            0.741 ± 0.045
#               V-score:                            0.716 ± 0.07
#               Silhouette-score(euc):              0.371 ± 0.022
#               Silhouette-score(cos):              0.611 ± 0.058
#               Adjusted-rand-score:                0.67 ± 0.133
#
#        K-means(cos)
#               H-score:                            0.813 ± 0.0
#               C-score:                            0.813 ± 0.0
#               V-score:                            0.813 ± 0.0
#               Silhouette-score(euc):              0.533 ± 0.0
#               Silhouette-score(cos):              0.704 ± 0.0
#               Adjusted-rand-score:                0.861 ± 0.0
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.536
#               C-score:                            0.678
#               V-score:                            0.599
#               Silhouette-score(euc):              0.37
#               Silhouette-score(cos):              0.497
#               Adjusted-rand-score:                0.441
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.663
#               C-score:                            0.672
#               V-score:                            0.668
#               Silhouette-score(euc):              0.323
#               Silhouette-score(cos):              0.577
#               Adjusted-rand-score:                0.678
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=symmetric, beta=None)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.012000000104308128
#               Silhouette-score(cos):              -0.01600000075995922
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.708 ± 0.017
#               C-score:                            0.711 ± 0.019
#               V-score:                            0.71 ± 0.018
#               Silhouette-score(euc):              0.593999981880188 ± 0.003000000026077032
#               Silhouette-score(cos):              0.7540000081062317 ± 0.0020000000949949026
#               Adjusted-rand-score:                0.746 ± 0.016
#
#        K-means(cos)
#               H-score:                            0.695 ± 0.005
#               C-score:                            0.694 ± 0.006
#               V-score:                            0.695 ± 0.005
#               Silhouette-score(euc):              0.619 ± 0.002
#               Silhouette-score(cos):              0.759 ± 0.002
#               Adjusted-rand-score:                0.739 ± 0.007
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.665
#               C-score:                            0.664
#               V-score:                            0.665
#               Silhouette-score(euc):              0.578000009059906
#               Silhouette-score(cos):              0.7239999771118164
#               Adjusted-rand-score:                0.71
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.648
#               C-score:                            0.664
#               V-score:                            0.656
#               Silhouette-score(euc):              0.5540000200271606
#               Silhouette-score(cos):              0.671999990940094
#               Adjusted-rand-score:                0.638
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=20, alpha=symmetric, beta=None)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.004999999888241291
#               Silhouette-score(cos):              -0.007000000216066837
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.382 ± 0.048
#               C-score:                            0.466 ± 0.033
#               V-score:                            0.419 ± 0.042
#               Silhouette-score(euc):              0.16200000047683716 ± 0.020999999716877937
#               Silhouette-score(cos):              0.23999999463558197 ± 0.017000000923871994
#               Adjusted-rand-score:                0.262 ± 0.057
#
#        K-means(cos)
#               H-score:                            0.468 ± 0.068
#               C-score:                            0.506 ± 0.067
#               V-score:                            0.486 ± 0.068
#               Silhouette-score(euc):              0.175 ± 0.016
#               Silhouette-score(cos):              0.257 ± 0.023
#               Adjusted-rand-score:                0.404 ± 0.072
#
#        DBSCAN(euc)
#               H-score:                            0.002
#               C-score:                            0.017
#               V-score:                            0.003
#               Silhouette-score(euc):              -0.06700000166893005
#               Silhouette-score(cos):              0.01600000075995922
#               Adjusted-rand-score:                -0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.248
#               C-score:                            0.384
#               V-score:                            0.301
#               Silhouette-score(euc):              0.14100000262260437
#               Silhouette-score(cos):              0.1599999964237213
#               Adjusted-rand-score:                0.1
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.265
#               C-score:                            0.368
#               V-score:                            0.308
#               Silhouette-score(euc):              0.1379999965429306
#               Silhouette-score(cos):              0.17599999904632568
#               Adjusted-rand-score:                0.136
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=50, alpha=symmetric, beta=None)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.004999999888241291
#               Silhouette-score(cos):              -0.004999999888241291
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.274 ± 0.096
#               C-score:                            0.408 ± 0.085
#               V-score:                            0.326 ± 0.097
#               Silhouette-score(euc):              0.07400000095367432 ± 0.01899999938905239
#               Silhouette-score(cos):              0.12399999797344208 ± 0.024000000208616257
#               Adjusted-rand-score:                0.147 ± 0.11
#
#        K-means(cos)
#               H-score:                            0.336 ± 0.085
#               C-score:                            0.414 ± 0.072
#               V-score:                            0.37 ± 0.08
#               Silhouette-score(euc):              0.098 ± 0.01
#               Silhouette-score(cos):              0.152 ± 0.015
#               Adjusted-rand-score:                0.225 ± 0.125
#
#        DBSCAN(euc)
#               H-score:                            0.247
#               C-score:                            0.225
#               V-score:                            0.235
#               Silhouette-score(euc):              -0.1509999930858612
#               Silhouette-score(cos):              -0.2540000081062317
#               Adjusted-rand-score:                0.127
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            0.01
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.13699999451637268
#               Silhouette-score(cos):              -0.00800000037997961
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.196
#               C-score:                            0.339
#               V-score:                            0.248
#               Silhouette-score(euc):              0.07000000029802322
#               Silhouette-score(cos):              0.10199999809265137
#               Adjusted-rand-score:                0.042
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.172
#               C-score:                            0.356
#               V-score:                            0.232
#               Silhouette-score(euc):              0.04600000008940697
#               Silhouette-score(cos):              0.04899999871850014
#               Adjusted-rand-score:                0.076
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=0.1, beta=0.1)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.010999999940395355
#               Silhouette-score(cos):              -0.01600000075995922
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.515 ± 0.023
#               C-score:                            0.535 ± 0.024
#               V-score:                            0.524 ± 0.024
#               Silhouette-score(euc):              0.5699999928474426 ± 0.0010000000474974513
#               Silhouette-score(cos):              0.7310000061988831 ± 0.009999999776482582
#               Adjusted-rand-score:                0.493 ± 0.026
#
#        K-means(cos)
#               H-score:                            0.534 ± 0.012
#               C-score:                            0.567 ± 0.025
#               V-score:                            0.55 ± 0.015
#               Silhouette-score(euc):              0.599 ± 0.007
#               Silhouette-score(cos):              0.746 ± 0.009
#               Adjusted-rand-score:                0.519 ± 0.012
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.545
#               C-score:                            0.581
#               V-score:                            0.563
#               Silhouette-score(euc):              0.5320000052452087
#               Silhouette-score(cos):              0.6679999828338623
#               Adjusted-rand-score:                0.522
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.555
#               C-score:                            0.585
#               V-score:                            0.57
#               Silhouette-score(euc):              0.5389999747276306
#               Silhouette-score(cos):              0.6970000267028809
#               Adjusted-rand-score:                0.543
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=0.5, beta=0.1)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.012000000104308128
#               Silhouette-score(cos):              -0.01600000075995922
#               Adjusted-rand-score:                0.0
#
#        K-means(euc)
#               H-score:                            0.715 ± 0.062
#               C-score:                            0.718 ± 0.06
#               V-score:                            0.717 ± 0.061
#               Silhouette-score(euc):              0.5419999957084656 ± 0.03999999910593033
#               Silhouette-score(cos):              0.7210000157356262 ± 0.04899999871850014
#               Adjusted-rand-score:                0.751 ± 0.087
#
#        K-means(cos)
#               H-score:                            0.747 ± 0.003
#               C-score:                            0.746 ± 0.003
#               V-score:                            0.747 ± 0.003
#               Silhouette-score(euc):              0.583 ± 0.0
#               Silhouette-score(cos):              0.742 ± 0.001
#               Adjusted-rand-score:                0.794 ± 0.003
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.689
#               C-score:                            0.698
#               V-score:                            0.693
#               Silhouette-score(euc):              0.5440000295639038
#               Silhouette-score(cos):              0.7049999833106995
#               Adjusted-rand-score:                0.711
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.661
#               C-score:                            0.664
#               V-score:                            0.662
#               Silhouette-score(euc):              0.5270000100135803
#               Silhouette-score(cos):              0.6800000071525574
#               Adjusted-rand-score:                0.666
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=0.5, beta=0.5)
#        Random
#               H-score:                            0.002
#               C-score:                            0.002
#               V-score:                            0.002
#               Silhouette-score(euc):              -0.014000000432133675
#               Silhouette-score(cos):              -0.019999999552965164
#               Adjusted-rand-score:                0.001
#
#        K-means(euc)
#               H-score:                            0.724 ± 0.0
#               C-score:                            0.724 ± 0.0
#               V-score:                            0.724 ± 0.0
#               Silhouette-score(euc):              0.6079999804496765 ± 0.0
#               Silhouette-score(cos):              0.7850000262260437 ± 0.0
#               Adjusted-rand-score:                0.775 ± 0.001
#
#        K-means(cos)
#               H-score:                            0.733 ± 0.0
#               C-score:                            0.734 ± 0.0
#               V-score:                            0.733 ± 0.0
#               Silhouette-score(euc):              0.638 ± 0.0
#               Silhouette-score(cos):              0.79 ± 0.0
#               Adjusted-rand-score:                0.784 ± 0.0
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.706
#               C-score:                            0.707
#               V-score:                            0.706
#               Silhouette-score(euc):              0.5929999947547913
#               Silhouette-score(cos):              0.7599999904632568
#               Adjusted-rand-score:                0.765
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.594
#               C-score:                            0.617
#               V-score:                            0.606
#               Silhouette-score(euc):              0.531000018119812
#               Silhouette-score(cos):              0.6539999842643738
#               Adjusted-rand-score:                0.619
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=2, beta=0.1)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.009999999776482582
#               Silhouette-score(cos):              -0.013000000268220901
#               Adjusted-rand-score:                0.0
#
#        K-means(euc)
#               H-score:                            0.634 ± 0.004
# ...
#               Silhouette-score(cos):              0.671 ± 0.009
#               Adjusted-rand-score:                0.693 ± 0.009
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.567
#               C-score:                            0.601
#               V-score:                            0.583
#               Silhouette-score(euc):              0.4440000057220459
#               Silhouette-score(cos):              0.5770000219345093
#               Adjusted-rand-score:                0.501
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.51
#               C-score:                            0.53
#               V-score:                            0.52
#               Silhouette-score(euc):              0.3269999921321869
#               Silhouette-score(cos):              0.4860000014305115
#               Adjusted-rand-score:                0.45
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=2, beta=0.5)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.012000000104308128
#               Silhouette-score(cos):              -0.017000000923871994
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.655 ± 0.001
#               C-score:                            0.67 ± 0.001
#               V-score:                            0.663 ± 0.001
#               Silhouette-score(euc):              0.4950000047683716 ± 0.0
#               Silhouette-score(cos):              0.6790000200271606 ± 0.0010000000474974513
#               Adjusted-rand-score:                0.646 ± 0.001
#
#        K-means(cos)
#               H-score:                            0.687 ± 0.0
#               C-score:                            0.694 ± 0.0
#               V-score:                            0.69 ± 0.0
#               Silhouette-score(euc):              0.531 ± 0.0
#               Silhouette-score(cos):              0.696 ± 0.0
#               Adjusted-rand-score:                0.706 ± 0.0
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.589
#               C-score:                            0.639
#               V-score:                            0.613
#               Silhouette-score(euc):              0.4490000009536743
#               Silhouette-score(cos):              0.5720000267028809
#               Adjusted-rand-score:                0.515
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.647
#               C-score:                            0.657
#               V-score:                            0.652
#               Silhouette-score(euc):              0.4729999899864197
#               Silhouette-score(cos):              0.6549999713897705
#               Adjusted-rand-score:                0.652
# ----------------------------------------------------------------------------------------------------
# LDA(ntop=5, alpha=0.1, beta=2)
#        Random
#               H-score:                            0.0
#               C-score:                            0.0
#               V-score:                            0.0
#               Silhouette-score(euc):              -0.009999999776482582
#               Silhouette-score(cos):              -0.012000000104308128
#               Adjusted-rand-score:                -0.001
#
#        K-means(euc)
#               H-score:                            0.655 ± 0.064
#               C-score:                            0.668 ± 0.066
#               V-score:                            0.661 ± 0.065
#               Silhouette-score(euc):              0.5669999718666077 ± 0.032999999821186066
#               Silhouette-score(cos):              0.6949999928474426 ± 0.03799999877810478
#               Adjusted-rand-score:                0.637 ± 0.082
#
#        K-means(cos)
#               H-score:                            0.663 ± 0.067
#               C-score:                            0.673 ± 0.062
#               V-score:                            0.668 ± 0.065
#               Silhouette-score(euc):              0.583 ± 0.033
#               Silhouette-score(cos):              0.696 ± 0.046
#               Adjusted-rand-score:                0.656 ± 0.1
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.714
#               C-score:                            0.719
#               V-score:                            0.716
#               Silhouette-score(euc):              0.5839999914169312
#               Silhouette-score(cos):              0.718999981880188
#               Adjusted-rand-score:                0.744
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.626
#               C-score:                            0.635
#               V-score:                            0.63
#               Silhouette-score(euc):              0.5540000200271606
#               Silhouette-score(cos):              0.6729999780654907
#               Adjusted-rand-score:                0.597
# ----------------------------------------------------------------------------------------------------
# LDA(NOUN, ntop=5, alpha=symmetric, beta=None)
#        Random
#               H-score:                            0.002
#               C-score:                            0.002
#               V-score:                            0.002
#               Silhouette-score(euc):              -0.01600000075995922
#               Silhouette-score(cos):              -0.01899999938905239
#               Adjusted-rand-score:                0.001
#
#        K-means(euc)
#               H-score:                            0.687 ± 0.065
#               C-score:                            0.697 ± 0.056
#               V-score:                            0.692 ± 0.061
#               Silhouette-score(euc):              0.6159999966621399 ± 0.04100000113248825
#               Silhouette-score(cos):              0.734000027179718 ± 0.04100000113248825
#               Adjusted-rand-score:                0.701 ± 0.086
#
#        K-means(cos)
#               H-score:                            0.699 ± 0.078
#               C-score:                            0.709 ± 0.066
#               V-score:                            0.704 ± 0.072
#               Silhouette-score(euc):              0.637 ± 0.042
#               Silhouette-score(cos):              0.739 ± 0.049
#               Adjusted-rand-score:                0.716 ± 0.106
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.732
#               C-score:                            0.735
#               V-score:                            0.734
#               Silhouette-score(euc):              0.6420000195503235
#               Silhouette-score(cos):              0.7599999904632568
#               Adjusted-rand-score:                0.767
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.72
#               C-score:                            0.728
#               V-score:                            0.724
#               Silhouette-score(euc):              0.6359999775886536
#               Silhouette-score(cos):              0.7369999885559082
#               Adjusted-rand-score:                0.744
# ----------------------------------------------------------------------------------------------------
# LDA(NOUN_JJ_VB, ntop=5, alpha=symmetric, beta=None)
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.010999999940395355
#               Silhouette-score(cos):              -0.014000000432133675
#               Adjusted-rand-score:                -0.0
#
#        K-means(euc)
#               H-score:                            0.736 ± 0.061
#               C-score:                            0.742 ± 0.047
#               V-score:                            0.739 ± 0.054
#               Silhouette-score(euc):              0.6299999952316284 ± 0.04699999839067459
#               Silhouette-score(cos):              0.7699999809265137 ± 0.05299999937415123
#               Adjusted-rand-score:                0.776 ± 0.086
#
#        K-means(cos)
#               H-score:                            0.736 ± 0.062
#               C-score:                            0.742 ± 0.049
#               V-score:                            0.739 ± 0.056
#               Silhouette-score(euc):              0.652 ± 0.042
#               Silhouette-score(cos):              0.776 ± 0.052
#               Adjusted-rand-score:                0.779 ± 0.086
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.645
#               C-score:                            0.662
#               V-score:                            0.653
#               Silhouette-score(euc):              0.5690000057220459
#               Silhouette-score(cos):              0.628000020980835
#               Adjusted-rand-score:                0.623
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.707
#               C-score:                            0.711
#               V-score:                            0.709
#               Silhouette-score(euc):              0.6190000176429749
#               Silhouette-score(cos):              0.734000027179718
#               Adjusted-rand-score:                0.745
# ----------------------------------------------------------------------------------------------------
# Bert-model
#        Random
#               H-score:                            0.001
#               C-score:                            0.001
#               V-score:                            0.001
#               Silhouette-score(euc):              -0.006
#               Silhouette-score(cos):              -0.011
#               Adjusted-rand-score:                0.0
#
#        K-means(euc)
#               H-score:                            0.183 ± 0.019
#               C-score:                            0.185 ± 0.019
#               V-score:                            0.184 ± 0.019
#               Silhouette-score(euc):              0.055 ± 0.007
#               Silhouette-score(cos):              0.103 ± 0.013
#               Adjusted-rand-score:                0.162 ± 0.01
#
#        K-means(cos)
#               H-score:                            0.206 ± 0.055
#               C-score:                            0.21 ± 0.056
#               V-score:                            0.208 ± 0.056
#               Silhouette-score(euc):              0.06 ± 0.005
#               Silhouette-score(cos):              0.112 ± 0.011
#               Adjusted-rand-score:                0.184 ± 0.04
#
#        DBSCAN(euc)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        DBSCAN(cos)
#               H-score:                            0.0
#               C-score:                            1.0
#               V-score:                            0.0
#               Silhouette-score(euc):              None
#               Silhouette-score(cos):              None
#               Adjusted-rand-score:                0.0
#
#        AgglomerativeClustering(euc, ward)
#               H-score:                            0.221
#               C-score:                            0.242
#               V-score:                            0.231
#               Silhouette-score(euc):              0.033
#               Silhouette-score(cos):              0.064
#               Adjusted-rand-score:                0.149
#
#        AgglomerativeClustering(cos, complete)
#               H-score:                            0.123
#               C-score:                            0.252
#               V-score:                            0.165
#               Silhouette-score(euc):              0.029
#               Silhouette-score(cos):              0.052
#               Adjusted-rand-score:                0.142
# ----------------------------------------------------------------------------------------------------
